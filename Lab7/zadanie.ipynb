# %% [markdown]
# ## Laboratorium 7
#
#
# ## Detekcja obiektów za pomocą Faster-RCNN
#
# ### Wprowadzenie
#
# Celem tej listy jest praktyczne zapoznanie się z działaniem dwuetapowych modeli do detekcji obiektów na przykładzie Faster R-CNN. Skorzystamy z gotowej implementacji modelu z pakietu [`torchvision`](https://github.com/pytorch/vision/blob/main/torchvision/models/detection/faster_rcnn.py). Jeżeli masz inny ulubiony model działający na podobnej zasadzie, możesz z niego skorzystać zamiast podanego. Podobnie implementacja - jeśli masz swoją ulubioną bibliotekę np. Detectron2, MMDetection, możesz z niej skorzystać.
#
# W zadaniu wykorzystany zostanie zbiór danych [_Chess Pieces Dataset_](https://public.roboflow.com/object-detection/chess-full) (autorstwa Roboflow, domena publiczna), ZIP z obrazami i anotacjami powinien być dołączony do instrukcji.
#
# Podczas realizacji tej listy większy nacisk położony zostanie na inferencję z użyciem Faster R-CNN niż na uczenie (które przeprowadzisz raz\*). Kluczowe komponenty w tej architekturze (RPN i RoIHeads) można konfigurować bez ponownego uczenia, dlatego badania skupią się na ich strojeniu. Aby zrozumieć działanie modelu, konieczne będzie spojrzenie w jego głąb, włącznie z częściowym wykonaniem. W tym celu warto mieć na podorędziu kod źródłowy, w szczególności implementacje następujących klas (uwaga - linki do najnowszej implementacji; upewnij się więc, że czytasz kod używanej przez siebie wersji biblioteki):
# * `FasterRCNN`: https://github.com/pytorch/vision/blob/main/torchvision/models/detection/faster_rcnn.py
# * `GeneralizedRCNN`: https://github.com/pytorch/vision/blob/main/torchvision/models/detection/generalized_rcnn.py
# * `RegionProposalNetwork`: https://github.com/pytorch/vision/blob/main/torchvision/models/detection/rpn.py
# * `RoIHeads`: https://github.com/pytorch/vision/blob/main/torchvision/models/detection/roi_heads.py
#
# Dogłębne zrozumienie procedury uczenia modelu nie będzie wymagane, niemniej należy mieć ogólną świadomość jak ten proces przebiega i jakie funkcje kosztu są wykorzystywane. Użyjemy gotowej implementacji z submodułu [`references.detection`](https://github.com/pytorch/vision/blob/main/references/detection/train.py) w nieco uproszczonej wersji. Ponieważ ten moduł **nie** jest domyślnie instalowaną częścią pakietu `torchvision`, do instrukcji dołączono jego kod w nieznacznie zmodyfikowanej wersji (`references_detection.zip`).
# Jeśli ciekawią Cię szczegóły procesu uczenia, zachęcam do lektury [artykułu](https://arxiv.org/abs/1506.01497) i analizy kodu implementacji.

# %%
# !pip install pycocotools

# %%
# pip install torchvision>=0.13

# %% [markdown]
# ### Zadanie 0: Uczenie
#
# Krokiem "zerowym" będzie przygotowanie wstępnie nauczonego modelu i douczenie go na docelowym zbiorze.
# Podany zestaw hiperparametrów powinien dawać przyzwoite (niekoniecznie idealne) wyniki - jeśli chcesz, śmiało dobierz swoje własne; nie spędzaj na tym jednak zbyt wiele czasu.
#
# Twoim zadaniem jest nie tylko przeklikanie poniższych komórek, ale przynajmniej ogólne zrozumienie procesu uczenia (przejrzyj implementację `train_one_epoch`) i struktury modelu.

# %%
import os
import time
import datetime

import torch
import torch.utils.data
import torchvision
import torchvision.models.detection as M
from torchvision.io.image import read_image
from torchvision.utils import draw_bounding_boxes
from torchvision.transforms.functional import to_pil_image

from detection import coco_utils, presets, utils, transforms
from detection.engine import train_one_epoch, evaluate

# %%
def get_dataset(img_root:str, file_name:str, train:bool=True):
  """Reimplementacja analogicznej funkcji z pakietu references, rozwiązująca drobną niekompatybilność w zbiorze CPD"""
  def fake_segmentation(image, target):
    for obj in target['annotations']:
      x, y, w, h = obj['bbox']
      segm = [x, y, x+w, y, x+w, y+h, x, y+h]
      obj['segmentation'] = [segm]
    return image, target

  tfs = transforms.Compose([
    fake_segmentation,
    coco_utils.ConvertCocoPolysToMask(),
    presets.DetectionPresetTrain(data_augmentation='hflip') if train else presets.DetectionPresetEval(),
    # jeśli chcesz dodać swoje własne augmentacje, możesz zrobić to tutaj
  ])
  ds = coco_utils.CocoDetection(img_root, file_name, transforms=tfs)
  return ds

# %%
# Konfiguracja hiperparametrów
LR = 0.001 # powinno być dobrze dla 1 GPU
WDECAY = 0.0001
EPOCHS = 25
VAL_FREQ = 5 # walidacja i checkpointowanie co N epok
BATCH_SIZE = 2 # dobierz pod możliwości sprzętowe
NUM_WORKERS = 0 # j/w
NUM_CLASSES = 14
DEVICE = 'cuda:0'
# DEVICE = 'cpu'
DATASET_ROOT = 'chess/'
OUTPUT_DIR = 'out2/'

# %%
# Zaczytanie datasetów
chess_train = get_dataset(os.path.join(DATASET_ROOT, 'train'), os.path.join(DATASET_ROOT, 'train/_annotations.coco.json'))
chess_val = get_dataset(os.path.join(DATASET_ROOT, 'valid'), os.path.join(DATASET_ROOT, 'valid/_annotations.coco.json'))
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
# samplery i loadery
train_sampler = torch.utils.data.RandomSampler(chess_train)
train_batch_sampler = torch.utils.data.BatchSampler(train_sampler, BATCH_SIZE, drop_last=True)
train_loader = torch.utils.data.DataLoader(
  chess_train, batch_sampler=train_batch_sampler, num_workers=NUM_WORKERS, collate_fn=utils.collate_fn
)

val_sampler = torch.utils.data.SequentialSampler(chess_val)
val_loader = torch.utils.data.DataLoader(
  chess_val, batch_size=1, sampler=val_sampler, num_workers=NUM_WORKERS, collate_fn=utils.collate_fn
)

# %%
# Skonstruowanie modelu; tworzymy w wersji dla 91 klas aby zainicjować wagi wstępnie nauczone na COCO...
model = M.fasterrcnn_resnet50_fpn(weights=M.FasterRCNN_ResNet50_FPN_Weights.COCO_V1, num_classes=91).to(DEVICE)
# ...po czym zastępujemy predyktor mniejszym, dostosowanym do naszego zbioru:
model.roi_heads.box_predictor = M.faster_rcnn.FastRCNNPredictor(in_channels=1024, num_classes=NUM_CLASSES).to(DEVICE)

# %%
# model # zwróć uwagę na strukturę Box Predictora (dlaczego tyle out_features?)

# %%
# Zanim przejdziemy do uczenia pełnego modelu, wykonamy krótkie wstępne uczenie losowo zainicjowanego predyktora:
train_one_epoch(
  model=model,
  optimizer=torch.optim.AdamW(model.roi_heads.box_predictor.parameters(), lr=LR, weight_decay=WDECAY),
  data_loader=train_loader,
  device=DEVICE,
  epoch=0, print_freq=20, scaler=None
)
# Out:
# Epoch: [0]  [  0/101]  eta: 0:04:09  lr: 0.000011  loss: 3.9697 (3.9697)  loss_classifier: 2.5895 (2.5895)  loss_box_reg: 0.8995 (0.8995)  loss_objectness: 0.4389 (0.4389)  loss_rpn_box_reg: 0.0419 (0.0419)  time: 2.4683  data: 1.0170  max mem: 2507
# Epoch: [0]  [ 20/101]  eta: 0:01:04  lr: 0.000211  loss: 2.6453 (2.8731)  loss_classifier: 2.2393 (2.2178)  loss_box_reg: 0.4222 (0.3988)  loss_objectness: 0.1815 (0.2382)  loss_rpn_box_reg: 0.0170 (0.0183)  time: 0.7147  data: 0.2974  max mem: 2615
# Epoch: [0]  [ 40/101]  eta: 0:00:52  lr: 0.000411  loss: 1.5567 (2.3306)  loss_classifier: 0.7551 (1.5703)  loss_box_reg: 0.4152 (0.4093)  loss_objectness: 0.3578 (0.3266)  loss_rpn_box_reg: 0.0255 (0.0244)  time: 0.9103  data: 0.4084  max mem: 2652
# Epoch: [0]  [ 60/101]  eta: 0:00:35  lr: 0.000610  loss: 1.4571 (2.0419)  loss_classifier: 0.6097 (1.2474)  loss_box_reg: 0.3344 (0.3900)  loss_objectness: 0.4600 (0.3774)  loss_rpn_box_reg: 0.0303 (0.0272)  time: 0.9165  data: 0.4401  max mem: 2690
# Epoch: [0]  [ 80/101]  eta: 0:00:17  lr: 0.000810  loss: 0.9059 (1.7672)  loss_classifier: 0.4107 (1.0318)  loss_box_reg: 0.2262 (0.3472)  loss_objectness: 0.2491 (0.3617)  loss_rpn_box_reg: 0.0179 (0.0267)  time: 0.7253  data: 0.3217  max mem: 2690
# Epoch: [0]  [100/101]  eta: 0:00:00  lr: 0.001000  loss: 1.0126 (1.6128)  loss_classifier: 0.3253 (0.8960)  loss_box_reg: 0.2118 (0.3222)  loss_objectness: 0.3520 (0.3675)  loss_rpn_box_reg: 0.0282 (0.0271)  time: 0.8514  data: 0.3960  max mem: 2690
# Epoch: [0] Total time: 0:01:24 (0.8401 s / it)

# %%
# Uczenie pełnego modelu
optimizer = torch.optim.AdamW(
  [p for p in model.parameters() if p.requires_grad],
  lr=LR,
  weight_decay=WDECAY
)
lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[10], gamma=0.1) # dobierz wartości jeśli trzeba

start_time = time.time()
for epoch in range(EPOCHS):
    train_one_epoch(model, optimizer, train_loader, DEVICE, epoch, 20, None)
    lr_scheduler.step()

    # eval and checkpoint every VAL_FREQ epochs
    if (epoch+1) % VAL_FREQ == 0:
      checkpoint = {
          "model": model.state_dict(),
          "optimizer": optimizer.state_dict(),
          "lr_scheduler": lr_scheduler.state_dict(),
          "epoch": epoch,
      }
      utils.save_on_master(checkpoint, os.path.join(OUTPUT_DIR, f"model_{epoch}.pth"))
      utils.save_on_master(checkpoint, os.path.join(OUTPUT_DIR, "checkpoint.pth"))
      evaluate(model, val_loader, device=DEVICE)

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print(f"Training time {total_time_str}")
# Out:
# Epoch: [0]  [  0/101]  eta: 0:02:56  lr: 0.000011  loss: 0.9247 (0.9247)  loss_classifier: 0.4711 (0.4711)  loss_box_reg: 0.3517 (0.3517)  loss_objectness: 0.0318 (0.0318)  loss_rpn_box_reg: 0.0701 (0.0701)  time: 1.7450  data: 0.2900  max mem: 2902
# Epoch: [0]  [ 20/101]  eta: 0:02:53  lr: 0.000211  loss: 0.8150 (0.8321)  loss_classifier: 0.4565 (0.4457)  loss_box_reg: 0.3311 (0.3341)  loss_objectness: 0.0078 (0.0097)  loss_rpn_box_reg: 0.0317 (0.0425)  time: 2.1662  data: 0.2059  max mem: 3178
# Epoch: [0]  [ 40/101]  eta: 0:02:04  lr: 0.000411  loss: 0.8402 (0.8766)  loss_classifier: 0.4545 (0.4767)  loss_box_reg: 0.3206 (0.3493)  loss_objectness: 0.0046 (0.0092)  loss_rpn_box_reg: 0.0360 (0.0415)  time: 1.9162  data: 0.2331  max mem: 3201
# Epoch: [0]  [ 60/101]  eta: 0:01:21  lr: 0.000610  loss: 0.8593 (0.9078)  loss_classifier: 0.4612 (0.4822)  loss_box_reg: 0.3684 (0.3631)  loss_objectness: 0.0021 (0.0110)  loss_rpn_box_reg: 0.0272 (0.0516)  time: 1.8889  data: 0.1932  max mem: 3215
# Epoch: [0]  [ 80/101]  eta: 0:00:41  lr: 0.000810  loss: 0.8177 (0.8693)  loss_classifier: 0.4009 (0.4571)  loss_box_reg: 0.3612 (0.3495)  loss_objectness: 0.0132 (0.0125)  loss_rpn_box_reg: 0.0282 (0.0502)  time: 1.9196  data: 0.1827  max mem: 3215
# Epoch: [0]  [100/101]  eta: 0:00:01  lr: 0.001000  loss: 0.8750 (0.8642)  loss_classifier: 0.4462 (0.4530)  loss_box_reg: 0.3756 (0.3487)  loss_objectness: 0.0092 (0.0129)  loss_rpn_box_reg: 0.0325 (0.0496)  time: 1.9064  data: 0.1888  max mem: 3215
# Epoch: [0] Total time: 0:03:17 (1.9574 s / it)
# Epoch: [1]  [  0/101]  eta: 0:02:55  lr: 0.001000  loss: 0.6458 (0.6458)  loss_classifier: 0.3092 (0.3092)  loss_box_reg: 0.3148 (0.3148)  loss_objectness: 0.0103 (0.0103)  loss_rpn_box_reg: 0.0115 (0.0115)  time: 1.7367  data: 0.1350  max mem: 3215
# Epoch: [1]  [ 20/101]  eta: 0:02:30  lr: 0.001000  loss: 0.8363 (0.8587)  loss_classifier: 0.4730 (0.4775)  loss_box_reg: 0.2922 (0.3256)  loss_objectness: 0.0051 (0.0132)  loss_rpn_box_reg: 0.0213 (0.0425)  time: 1.8670  data: 0.2030  max mem: 3215
# Epoch: [1]  [ 40/101]  eta: 0:01:49  lr: 0.001000  loss: 1.2173 (1.0824)  loss_classifier: 0.6380 (0.5667)  loss_box_reg: 0.4426 (0.3807)  loss_objectness: 0.0390 (0.0674)  loss_rpn_box_reg: 0.0657 (0.0676)  time: 1.7121  data: 0.2190  max mem: 3215
# Epoch: [1]  [ 60/101]  eta: 0:01:09  lr: 0.001000  loss: 1.0347 (1.0367)  loss_classifier: 0.5161 (0.5337)  loss_box_reg: 0.4073 (0.3857)  loss_objectness: 0.0077 (0.0522)  loss_rpn_box_reg: 0.0355 (0.0651)  time: 1.5145  data: 0.1764  max mem: 3215
# Epoch: [1]  [ 80/101]  eta: 0:00:36  lr: 0.001000  loss: 0.9530 (1.0023)  loss_classifier: 0.4719 (0.5120)  loss_box_reg: 0.4151 (0.3870)  loss_objectness: 0.0118 (0.0426)  loss_rpn_box_reg: 0.0433 (0.0607)  time: 1.8557  data: 0.1983  max mem: 3215
# Epoch: [1]  [100/101]  eta: 0:00:01  lr: 0.001000  loss: 0.9879 (1.0025)  loss_classifier: 0.4957 (0.5112)  loss_box_reg: 0.4179 (0.3967)  loss_objectness: 0.0041 (0.0355)  loss_rpn_box_reg: 0.0583 (0.0592)  time: 1.8767  data: 0.2245  max mem: 3215
# Epoch: [1] Total time: 0:02:58 (1.7650 s / it)
# Epoch: [2]  [  0/101]  eta: 0:03:09  lr: 0.001000  loss: 0.2188 (0.2188)  loss_classifier: 0.0985 (0.0985)  loss_box_reg: 0.1171 (0.1171)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 1.8810  data: 0.0870  max mem: 3215
# Epoch: [2]  [ 20/101]  eta: 0:02:40  lr: 0.001000  loss: 0.8848 (0.8169)  loss_classifier: 0.4488 (0.4042)  loss_box_reg: 0.3623 (0.3549)  loss_objectness: 0.0035 (0.0113)  loss_rpn_box_reg: 0.0405 (0.0465)  time: 1.9912  data: 0.1947  max mem: 3215
# Epoch: [2]  [ 40/101]  eta: 0:01:58  lr: 0.001000  loss: 0.8186 (0.7980)  loss_classifier: 0.4053 (0.4043)  loss_box_reg: 0.3408 (0.3374)  loss_objectness: 0.0058 (0.0109)  loss_rpn_box_reg: 0.0347 (0.0454)  time: 1.8988  data: 0.1908  max mem: 3217
# Epoch: [2]  [ 60/101]  eta: 0:01:18  lr: 0.001000  loss: 0.8406 (0.8358)  loss_classifier: 0.4573 (0.4403)  loss_box_reg: 0.3299 (0.3375)  loss_objectness: 0.0054 (0.0107)  loss_rpn_box_reg: 0.0414 (0.0473)  time: 1.8560  data: 0.2160  max mem: 3217
# Epoch: [2]  [ 80/101]  eta: 0:00:40  lr: 0.001000  loss: 0.7656 (0.8283)  loss_classifier: 0.4228 (0.4441)  loss_box_reg: 0.2599 (0.3254)  loss_objectness: 0.0075 (0.0130)  loss_rpn_box_reg: 0.0364 (0.0458)  time: 2.0202  data: 0.1857  max mem: 3217
# Epoch: [2]  [100/101]  eta: 0:00:01  lr: 0.001000  loss: 1.2775 (0.9900)  loss_classifier: 0.6811 (0.4992)  loss_box_reg: 0.5077 (0.3661)  loss_objectness: 0.0433 (0.0618)  loss_rpn_box_reg: 0.0832 (0.0629)  time: 1.6688  data: 0.2284  max mem: 3217
# Epoch: [2] Total time: 0:03:10 (1.8870 s / it)
# Epoch: [3]  [  0/101]  eta: 0:02:35  lr: 0.001000  loss: 0.1646 (0.1646)  loss_classifier: 0.0847 (0.0847)  loss_box_reg: 0.0585 (0.0585)  loss_objectness: 0.0140 (0.0140)  loss_rpn_box_reg: 0.0075 (0.0075)  time: 1.5400  data: 0.0860  max mem: 3217
# Epoch: [3]  [ 20/101]  eta: 0:02:22  lr: 0.001000  loss: 0.9238 (0.8102)  loss_classifier: 0.4715 (0.4265)  loss_box_reg: 0.3727 (0.3253)  loss_objectness: 0.0116 (0.0168)  loss_rpn_box_reg: 0.0311 (0.0416)  time: 1.7715  data: 0.1754  max mem: 3217
# Epoch: [3]  [ 40/101]  eta: 0:01:50  lr: 0.001000  loss: 0.8557 (0.7930)  loss_classifier: 0.4571 (0.4251)  loss_box_reg: 0.3235 (0.3044)  loss_objectness: 0.0127 (0.0226)  loss_rpn_box_reg: 0.0345 (0.0409)  time: 1.8738  data: 0.1820  max mem: 3217
# Epoch: [3]  [ 60/101]  eta: 0:01:12  lr: 0.001000  loss: 0.9300 (0.8884)  loss_classifier: 0.5243 (0.4806)  loss_box_reg: 0.3598 (0.3405)  loss_objectness: 0.0141 (0.0222)  loss_rpn_box_reg: 0.0372 (0.0452)  time: 1.6343  data: 0.2134  max mem: 3217
# Epoch: [3]  [ 80/101]  eta: 0:00:36  lr: 0.001000  loss: 0.9521 (0.8988)  loss_classifier: 0.4566 (0.4809)  loss_box_reg: 0.3808 (0.3493)  loss_objectness: 0.0162 (0.0202)  loss_rpn_box_reg: 0.0611 (0.0485)  time: 1.7282  data: 0.2305  max mem: 3217
# Epoch: [3]  [100/101]  eta: 0:00:01  lr: 0.001000  loss: 0.6726 (0.8844)  loss_classifier: 0.3473 (0.4718)  loss_box_reg: 0.2960 (0.3437)  loss_objectness: 0.0066 (0.0186)  loss_rpn_box_reg: 0.0171 (0.0503)  time: 1.7472  data: 0.2117  max mem: 3217
# Epoch: [3] Total time: 0:02:56 (1.7490 s / it)
# Epoch: [4]  [  0/101]  eta: 0:03:56  lr: 0.001000  loss: 0.8341 (0.8341)  loss_classifier: 0.4478 (0.4478)  loss_box_reg: 0.3302 (0.3302)  loss_objectness: 0.0056 (0.0056)  loss_rpn_box_reg: 0.0505 (0.0505)  time: 2.3410  data: 0.2150  max mem: 3217
# Epoch: [4]  [ 20/101]  eta: 0:03:25  lr: 0.001000  loss: 0.6128 (0.5938)  loss_classifier: 0.3684 (0.3325)  loss_box_reg: 0.2346 (0.2196)  loss_objectness: 0.0018 (0.0049)  loss_rpn_box_reg: 0.0215 (0.0368)  time: 2.5494  data: 0.1939  max mem: 3217
# Epoch: [4]  [ 40/101]  eta: 0:02:58  lr: 0.001000  loss: 0.6901 (0.6244)  loss_classifier: 0.4091 (0.3533)  loss_box_reg: 0.2366 (0.2270)  loss_objectness: 0.0022 (0.0043)  loss_rpn_box_reg: 0.0434 (0.0398)  time: 3.3461  data: 0.2636  max mem: 3217
# Epoch: [4]  [ 60/101]  eta: 0:02:03  lr: 0.001000  loss: 0.7796 (0.6872)  loss_classifier: 0.4428 (0.3863)  loss_box_reg: 0.2672 (0.2451)  loss_objectness: 0.0045 (0.0122)  loss_rpn_box_reg: 0.0486 (0.0435)  time: 3.1776  data: 0.3367  max mem: 3217
# Epoch: [4]  [ 80/101]  eta: 0:01:02  lr: 0.001000  loss: 0.7933 (0.7086)  loss_classifier: 0.4470 (0.3999)  loss_box_reg: 0.2807 (0.2540)  loss_objectness: 0.0063 (0.0115)  loss_rpn_box_reg: 0.0387 (0.0432)  time: 2.9281  data: 0.2757  max mem: 3217
# Epoch: [4]  [100/101]  eta: 0:00:02  lr: 0.001000  loss: 0.7582 (0.7866)  loss_classifier: 0.4117 (0.4542)  loss_box_reg: 0.2863 (0.2769)  loss_objectness: 0.0021 (0.0113)  loss_rpn_box_reg: 0.0379 (0.0441)  time: 2.3778  data: 0.2592  max mem: 3217
# Epoch: [4] Total time: 0:04:49 (2.8706 s / it)
# Test:  [ 0/58]  eta: 0:00:41  model_time: 0.3650 (0.3650)  evaluator_time: 0.1438 (0.1438)  time: 0.7121  data: 0.1949  max mem: 3217
# Test:  [57/58]  eta: 0:00:00  model_time: 0.2964 (0.3114)  evaluator_time: 0.0015 (0.0053)  time: 0.4198  data: 0.1084  max mem: 3217
# Test: Total time: 0:00:25 (0.4472 s / it)
# Averaged stats: model_time: 0.2964 (0.3114)  evaluator_time: 0.0015 (0.0053)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.054
# Epoch: [5]  [  0/101]  eta: 0:04:22  lr: 0.001000  loss: 1.2206 (1.2206)  loss_classifier: 0.4103 (0.4103)  loss_box_reg: 0.3477 (0.3477)  loss_objectness: 0.0451 (0.0451)  loss_rpn_box_reg: 0.4174 (0.4174)  time: 2.6008  data: 0.2292  max mem: 3217
# Epoch: [5]  [ 20/101]  eta: 0:02:36  lr: 0.001000  loss: 1.0851 (1.2061)  loss_classifier: 0.5072 (0.5160)  loss_box_reg: 0.4175 (0.4171)  loss_objectness: 0.0801 (0.1701)  loss_rpn_box_reg: 0.0630 (0.1029)  time: 1.8940  data: 0.2197  max mem: 3217
# Epoch: [5]  [ 40/101]  eta: 0:02:00  lr: 0.001000  loss: 1.0322 (1.1716)  loss_classifier: 0.4893 (0.5243)  loss_box_reg: 0.4052 (0.4265)  loss_objectness: 0.0659 (0.1255)  loss_rpn_box_reg: 0.0510 (0.0952)  time: 2.0407  data: 0.2305  max mem: 3217
# Epoch: [5]  [ 60/101]  eta: 0:01:23  lr: 0.001000  loss: 0.9016 (1.0460)  loss_classifier: 0.4497 (0.4838)  loss_box_reg: 0.3492 (0.3869)  loss_objectness: 0.0380 (0.0991)  loss_rpn_box_reg: 0.0321 (0.0763)  time: 2.1308  data: 0.2203  max mem: 3217
# Epoch: [5]  [ 80/101]  eta: 0:00:43  lr: 0.001000  loss: 0.9957 (1.0162)  loss_classifier: 0.4640 (0.4736)  loss_box_reg: 0.3359 (0.3746)  loss_objectness: 0.0375 (0.0966)  loss_rpn_box_reg: 0.0608 (0.0714)  time: 2.2681  data: 0.2344  max mem: 3217
# Epoch: [5]  [100/101]  eta: 0:00:02  lr: 0.001000  loss: 0.8437 (0.9667)  loss_classifier: 0.4506 (0.4576)  loss_box_reg: 0.3300 (0.3602)  loss_objectness: 0.0334 (0.0844)  loss_rpn_box_reg: 0.0258 (0.0645)  time: 2.1681  data: 0.1957  max mem: 3217
# Epoch: [5] Total time: 0:03:32 (2.1053 s / it)
# Epoch: [6]  [  0/101]  eta: 0:02:38  lr: 0.001000  loss: 1.4916 (1.4916)  loss_classifier: 0.7568 (0.7568)  loss_box_reg: 0.5530 (0.5530)  loss_objectness: 0.0645 (0.0645)  loss_rpn_box_reg: 0.1173 (0.1173)  time: 1.5714  data: 0.4386  max mem: 3217
# Epoch: [6]  [ 20/101]  eta: 0:03:01  lr: 0.001000  loss: 0.8875 (1.0355)  loss_classifier: 0.4580 (0.5403)  loss_box_reg: 0.3408 (0.3988)  loss_objectness: 0.0397 (0.0441)  loss_rpn_box_reg: 0.0471 (0.0523)  time: 2.2770  data: 0.2524  max mem: 3217
# Epoch: [6]  [ 40/101]  eta: 0:02:14  lr: 0.001000  loss: 0.9504 (0.9854)  loss_classifier: 0.5199 (0.5209)  loss_box_reg: 0.3298 (0.3759)  loss_objectness: 0.0391 (0.0413)  loss_rpn_box_reg: 0.0441 (0.0473)  time: 2.1759  data: 0.2125  max mem: 3217
# Epoch: [6]  [ 60/101]  eta: 0:01:29  lr: 0.001000  loss: 0.8266 (0.9309)  loss_classifier: 0.4376 (0.4928)  loss_box_reg: 0.2988 (0.3522)  loss_objectness: 0.0306 (0.0391)  loss_rpn_box_reg: 0.0302 (0.0468)  time: 2.1155  data: 0.2147  max mem: 3217
# Epoch: [6]  [ 80/101]  eta: 0:00:45  lr: 0.001000  loss: 0.7517 (0.8870)  loss_classifier: 0.3826 (0.4628)  loss_box_reg: 0.2835 (0.3319)  loss_objectness: 0.0482 (0.0468)  loss_rpn_box_reg: 0.0229 (0.0455)  time: 2.1916  data: 0.1996  max mem: 3217
# Epoch: [6]  [100/101]  eta: 0:00:02  lr: 0.001000  loss: 0.8405 (0.8538)  loss_classifier: 0.3486 (0.4305)  loss_box_reg: 0.3304 (0.3216)  loss_objectness: 0.0809 (0.0558)  loss_rpn_box_reg: 0.0333 (0.0458)  time: 1.7424  data: 0.1758  max mem: 3217
# Epoch: [6] Total time: 0:03:31 (2.0953 s / it)
# Epoch: [7]  [  0/101]  eta: 0:03:37  lr: 0.001000  loss: 1.2522 (1.2522)  loss_classifier: 0.5181 (0.5181)  loss_box_reg: 0.4928 (0.4928)  loss_objectness: 0.1610 (0.1610)  loss_rpn_box_reg: 0.0803 (0.0803)  time: 2.1542  data: 0.2561  max mem: 3217
# Epoch: [7]  [ 20/101]  eta: 0:03:08  lr: 0.001000  loss: 1.0012 (1.0484)  loss_classifier: 0.4058 (0.4631)  loss_box_reg: 0.3037 (0.3213)  loss_objectness: 0.1282 (0.1943)  loss_rpn_box_reg: 0.0628 (0.0697)  time: 2.3410  data: 0.2492  max mem: 3217
# Epoch: [7]  [ 40/101]  eta: 0:02:23  lr: 0.001000  loss: 0.8130 (1.3411)  loss_classifier: 0.3305 (0.5722)  loss_box_reg: 0.2244 (0.4080)  loss_objectness: 0.1839 (0.2359)  loss_rpn_box_reg: 0.0466 (0.1250)  time: 2.3781  data: 0.2863  max mem: 3217
# Epoch: [7]  [ 60/101]  eta: 0:01:35  lr: 0.001000  loss: 1.0882 (1.2348)  loss_classifier: 0.4970 (0.5452)  loss_box_reg: 0.3887 (0.3933)  loss_objectness: 0.1016 (0.1950)  loss_rpn_box_reg: 0.0560 (0.1012)  time: 2.2692  data: 0.2623  max mem: 3217
# Epoch: [7]  [ 80/101]  eta: 0:00:48  lr: 0.001000  loss: 1.1137 (1.1940)  loss_classifier: 0.5164 (0.5316)  loss_box_reg: 0.4053 (0.3947)  loss_objectness: 0.1160 (0.1766)  loss_rpn_box_reg: 0.0467 (0.0910)  time: 2.2564  data: 0.2906  max mem: 3217
# Epoch: [7]  [100/101]  eta: 0:00:02  lr: 0.001000  loss: 1.0493 (1.1363)  loss_classifier: 0.4655 (0.5079)  loss_box_reg: 0.4039 (0.3838)  loss_objectness: 0.0890 (0.1619)  loss_rpn_box_reg: 0.0459 (0.0827)  time: 2.2889  data: 0.2567  max mem: 3217
# Epoch: [7] Total time: 0:03:52 (2.3053 s / it)
# Epoch: [8]  [  0/101]  eta: 0:03:24  lr: 0.001000  loss: 0.2005 (0.2005)  loss_classifier: 0.0783 (0.0783)  loss_box_reg: 0.0666 (0.0666)  loss_objectness: 0.0489 (0.0489)  loss_rpn_box_reg: 0.0067 (0.0067)  time: 2.0252  data: 0.1362  max mem: 3217
# Epoch: [8]  [ 20/101]  eta: 0:02:51  lr: 0.001000  loss: 0.9749 (0.9100)  loss_classifier: 0.4290 (0.3955)  loss_box_reg: 0.3863 (0.3586)  loss_objectness: 0.0928 (0.1040)  loss_rpn_box_reg: 0.0453 (0.0519)  time: 2.1264  data: 0.2503  max mem: 3217
# Epoch: [8]  [ 40/101]  eta: 0:02:04  lr: 0.001000  loss: 0.9520 (0.8974)  loss_classifier: 0.4233 (0.3925)  loss_box_reg: 0.3829 (0.3539)  loss_objectness: 0.0957 (0.1014)  loss_rpn_box_reg: 0.0416 (0.0495)  time: 1.9704  data: 0.2220  max mem: 3217
# Epoch: [8]  [ 60/101]  eta: 0:01:21  lr: 0.001000  loss: 0.9474 (0.8896)  loss_classifier: 0.4227 (0.3941)  loss_box_reg: 0.3559 (0.3448)  loss_objectness: 0.0804 (0.1011)  loss_rpn_box_reg: 0.0424 (0.0495)  time: 1.8902  data: 0.2263  max mem: 3217
# Epoch: [8]  [ 80/101]  eta: 0:00:40  lr: 0.001000  loss: 0.8044 (0.8712)  loss_classifier: 0.3875 (0.3876)  loss_box_reg: 0.3169 (0.3366)  loss_objectness: 0.0745 (0.0994)  loss_rpn_box_reg: 0.0344 (0.0477)  time: 1.7671  data: 0.2101  max mem: 3217
# Epoch: [8]  [100/101]  eta: 0:00:01  lr: 0.001000  loss: 1.0049 (0.9057)  loss_classifier: 0.4459 (0.4033)  loss_box_reg: 0.3800 (0.3504)  loss_objectness: 0.1060 (0.1022)  loss_rpn_box_reg: 0.0522 (0.0498)  time: 1.8082  data: 0.2546  max mem: 3217
# Epoch: [8] Total time: 0:03:13 (1.9137 s / it)
# Epoch: [9]  [  0/101]  eta: 0:02:55  lr: 0.001000  loss: 0.2062 (0.2062)  loss_classifier: 0.0892 (0.0892)  loss_box_reg: 0.0692 (0.0692)  loss_objectness: 0.0452 (0.0452)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.7421  data: 0.0860  max mem: 3217
# Epoch: [9]  [ 20/101]  eta: 0:02:39  lr: 0.001000  loss: 0.9481 (0.7455)  loss_classifier: 0.4184 (0.3269)  loss_box_reg: 0.3524 (0.2886)  loss_objectness: 0.0911 (0.0887)  loss_rpn_box_reg: 0.0454 (0.0413)  time: 1.9753  data: 0.2129  max mem: 3217
# Epoch: [9]  [ 40/101]  eta: 0:02:04  lr: 0.001000  loss: 0.9000 (0.8497)  loss_classifier: 0.3909 (0.3700)  loss_box_reg: 0.3695 (0.3365)  loss_objectness: 0.0983 (0.0963)  loss_rpn_box_reg: 0.0423 (0.0468)  time: 2.1199  data: 0.2439  max mem: 3217
# Epoch: [9]  [ 60/101]  eta: 0:01:22  lr: 0.001000  loss: 0.8947 (0.8492)  loss_classifier: 0.3798 (0.3696)  loss_box_reg: 0.3601 (0.3355)  loss_objectness: 0.0979 (0.0966)  loss_rpn_box_reg: 0.0518 (0.0475)  time: 1.9233  data: 0.2186  max mem: 3217
# Epoch: [9]  [ 80/101]  eta: 0:00:41  lr: 0.001000  loss: 0.8026 (0.8449)  loss_classifier: 0.3528 (0.3679)  loss_box_reg: 0.3273 (0.3330)  loss_objectness: 0.0793 (0.0969)  loss_rpn_box_reg: 0.0367 (0.0471)  time: 1.8683  data: 0.2237  max mem: 3217
# Epoch: [9]  [100/101]  eta: 0:00:01  lr: 0.001000  loss: 0.9219 (0.8553)  loss_classifier: 0.4143 (0.3747)  loss_box_reg: 0.3428 (0.3340)  loss_objectness: 0.1083 (0.0983)  loss_rpn_box_reg: 0.0612 (0.0482)  time: 1.9315  data: 0.2448  max mem: 3217
# Epoch: [9] Total time: 0:03:18 (1.9615 s / it)
# Test:  [ 0/58]  eta: 0:00:30  model_time: 0.3490 (0.3490)  evaluator_time: 0.0050 (0.0050)  time: 0.5320  data: 0.1680  max mem: 3217
# Test:  [57/58]  eta: 0:00:00  model_time: 0.2069 (0.2189)  evaluator_time: 0.0020 (0.0033)  time: 0.3471  data: 0.1210  max mem: 3217
# Test: Total time: 0:00:21 (0.3623 s / it)
# Averaged stats: model_time: 0.2069 (0.2189)  evaluator_time: 0.0020 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.062
# Epoch: [10]  [  0/101]  eta: 0:03:22  lr: 0.000100  loss: 0.9743 (0.9743)  loss_classifier: 0.4291 (0.4291)  loss_box_reg: 0.3343 (0.3343)  loss_objectness: 0.1319 (0.1319)  loss_rpn_box_reg: 0.0790 (0.0790)  time: 2.0020  data: 0.2670  max mem: 3217
# Epoch: [10]  [ 20/101]  eta: 0:02:44  lr: 0.000100  loss: 0.9135 (0.7878)  loss_classifier: 0.4003 (0.3437)  loss_box_reg: 0.3385 (0.2937)  loss_objectness: 0.1085 (0.1006)  loss_rpn_box_reg: 0.0477 (0.0498)  time: 2.0283  data: 0.2352  max mem: 3217
# Epoch: [10]  [ 40/101]  eta: 0:01:58  lr: 0.000100  loss: 0.8889 (0.7839)  loss_classifier: 0.3852 (0.3410)  loss_box_reg: 0.3344 (0.2998)  loss_objectness: 0.0900 (0.0966)  loss_rpn_box_reg: 0.0376 (0.0464)  time: 1.8505  data: 0.2167  max mem: 3217
# Epoch: [10]  [ 60/101]  eta: 0:01:19  lr: 0.000100  loss: 0.7259 (0.7412)  loss_classifier: 0.3287 (0.3235)  loss_box_reg: 0.2888 (0.2831)  loss_objectness: 0.0715 (0.0914)  loss_rpn_box_reg: 0.0308 (0.0432)  time: 1.9084  data: 0.1900  max mem: 3217
# Epoch: [10]  [ 80/101]  eta: 0:00:40  lr: 0.000100  loss: 0.8574 (0.7780)  loss_classifier: 0.3771 (0.3411)  loss_box_reg: 0.3319 (0.2954)  loss_objectness: 0.0975 (0.0952)  loss_rpn_box_reg: 0.0521 (0.0463)  time: 1.9357  data: 0.2410  max mem: 3217
# Epoch: [10]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.9054 (0.8039)  loss_classifier: 0.4093 (0.3542)  loss_box_reg: 0.3348 (0.3048)  loss_objectness: 0.1049 (0.0970)  loss_rpn_box_reg: 0.0620 (0.0478)  time: 2.0035  data: 0.2388  max mem: 3217
# Epoch: [10] Total time: 0:03:16 (1.9460 s / it)
# Epoch: [11]  [  0/101]  eta: 0:03:16  lr: 0.000100  loss: 0.8452 (0.8452)  loss_classifier: 0.4286 (0.4286)  loss_box_reg: 0.3080 (0.3080)  loss_objectness: 0.0789 (0.0789)  loss_rpn_box_reg: 0.0297 (0.0297)  time: 1.9480  data: 0.2000  max mem: 3217
# Epoch: [11]  [ 20/101]  eta: 0:02:24  lr: 0.000100  loss: 0.7238 (0.6525)  loss_classifier: 0.3291 (0.2958)  loss_box_reg: 0.2678 (0.2406)  loss_objectness: 0.0756 (0.0804)  loss_rpn_box_reg: 0.0298 (0.0356)  time: 1.7799  data: 0.1887  max mem: 3217
# Epoch: [11]  [ 40/101]  eta: 0:01:53  lr: 0.000100  loss: 0.8868 (0.7741)  loss_classifier: 0.4057 (0.3523)  loss_box_reg: 0.2996 (0.2826)  loss_objectness: 0.1084 (0.0926)  loss_rpn_box_reg: 0.0587 (0.0466)  time: 1.9512  data: 0.2544  max mem: 3217
# Epoch: [11]  [ 60/101]  eta: 0:01:18  lr: 0.000100  loss: 0.8171 (0.7965)  loss_classifier: 0.3824 (0.3638)  loss_box_reg: 0.3029 (0.2883)  loss_objectness: 0.0994 (0.0958)  loss_rpn_box_reg: 0.0469 (0.0487)  time: 2.0424  data: 0.2399  max mem: 3217
# Epoch: [11]  [ 80/101]  eta: 0:00:40  lr: 0.000100  loss: 0.7951 (0.7922)  loss_classifier: 0.3520 (0.3600)  loss_box_reg: 0.2782 (0.2871)  loss_objectness: 0.0905 (0.0965)  loss_rpn_box_reg: 0.0431 (0.0485)  time: 1.9377  data: 0.2267  max mem: 3217
# Epoch: [11]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.8068 (0.7821)  loss_classifier: 0.3740 (0.3559)  loss_box_reg: 0.2902 (0.2833)  loss_objectness: 0.0765 (0.0952)  loss_rpn_box_reg: 0.0360 (0.0477)  time: 1.9741  data: 0.2229  max mem: 3217
# Epoch: [11] Total time: 0:03:15 (1.9372 s / it)
# Epoch: [12]  [  0/101]  eta: 0:03:02  lr: 0.000100  loss: 0.3125 (0.3125)  loss_classifier: 0.1449 (0.1449)  loss_box_reg: 0.0988 (0.0988)  loss_objectness: 0.0554 (0.0554)  loss_rpn_box_reg: 0.0134 (0.0134)  time: 1.8070  data: 0.1320  max mem: 3217
# Epoch: [12]  [ 20/101]  eta: 0:02:46  lr: 0.000100  loss: 0.8928 (0.9081)  loss_classifier: 0.4034 (0.4170)  loss_box_reg: 0.2988 (0.3180)  loss_objectness: 0.1304 (0.1112)  loss_rpn_box_reg: 0.0674 (0.0618)  time: 2.0725  data: 0.2728  max mem: 3217
# Epoch: [12]  [ 40/101]  eta: 0:02:04  lr: 0.000100  loss: 0.8323 (0.8025)  loss_classifier: 0.3847 (0.3669)  loss_box_reg: 0.2687 (0.2835)  loss_objectness: 0.0893 (0.0993)  loss_rpn_box_reg: 0.0534 (0.0528)  time: 2.0088  data: 0.2054  max mem: 3217
# Epoch: [12]  [ 60/101]  eta: 0:01:22  lr: 0.000100  loss: 0.6298 (0.7504)  loss_classifier: 0.2768 (0.3462)  loss_box_reg: 0.2503 (0.2646)  loss_objectness: 0.0679 (0.0929)  loss_rpn_box_reg: 0.0309 (0.0467)  time: 1.9759  data: 0.1911  max mem: 3217
# Epoch: [12]  [ 80/101]  eta: 0:00:41  lr: 0.000100  loss: 0.8723 (0.7878)  loss_classifier: 0.4042 (0.3658)  loss_box_reg: 0.3042 (0.2769)  loss_objectness: 0.1043 (0.0961)  loss_rpn_box_reg: 0.0503 (0.0490)  time: 1.9340  data: 0.2499  max mem: 3217
# Epoch: [12]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.6305 (0.7667)  loss_classifier: 0.3115 (0.3562)  loss_box_reg: 0.2374 (0.2679)  loss_objectness: 0.0779 (0.0949)  loss_rpn_box_reg: 0.0208 (0.0477)  time: 1.6216  data: 0.1911  max mem: 3217
# Epoch: [12] Total time: 0:03:14 (1.9214 s / it)
# Epoch: [13]  [  0/101]  eta: 0:02:31  lr: 0.000100  loss: 1.1137 (1.1137)  loss_classifier: 0.5475 (0.5475)  loss_box_reg: 0.4183 (0.4183)  loss_objectness: 0.0937 (0.0937)  loss_rpn_box_reg: 0.0542 (0.0542)  time: 1.4980  data: 0.1960  max mem: 3217
# Epoch: [13]  [ 20/101]  eta: 0:02:01  lr: 0.000100  loss: 0.5877 (0.5985)  loss_classifier: 0.2768 (0.2783)  loss_box_reg: 0.2028 (0.2118)  loss_objectness: 0.0630 (0.0762)  loss_rpn_box_reg: 0.0216 (0.0321)  time: 1.4970  data: 0.1657  max mem: 3217
# Epoch: [13]  [ 40/101]  eta: 0:01:33  lr: 0.000100  loss: 0.8458 (0.7279)  loss_classifier: 0.3854 (0.3413)  loss_box_reg: 0.2814 (0.2501)  loss_objectness: 0.1041 (0.0913)  loss_rpn_box_reg: 0.0574 (0.0452)  time: 1.5582  data: 0.2279  max mem: 3217
# Epoch: [13]  [ 60/101]  eta: 0:01:04  lr: 0.000100  loss: 0.7701 (0.7491)  loss_classifier: 0.3578 (0.3512)  loss_box_reg: 0.2708 (0.2572)  loss_objectness: 0.0757 (0.0939)  loss_rpn_box_reg: 0.0416 (0.0469)  time: 1.6609  data: 0.2227  max mem: 3217
# Epoch: [13]  [ 80/101]  eta: 0:00:33  lr: 0.000100  loss: 0.8109 (0.7612)  loss_classifier: 0.3868 (0.3572)  loss_box_reg: 0.2826 (0.2623)  loss_objectness: 0.0925 (0.0937)  loss_rpn_box_reg: 0.0528 (0.0480)  time: 1.6075  data: 0.2108  max mem: 3217
# Epoch: [13]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.8055 (0.7543)  loss_classifier: 0.3692 (0.3530)  loss_box_reg: 0.2689 (0.2601)  loss_objectness: 0.1030 (0.0937)  loss_rpn_box_reg: 0.0498 (0.0476)  time: 1.7185  data: 0.1972  max mem: 3217
# Epoch: [13] Total time: 0:02:42 (1.6074 s / it)
# Epoch: [14]  [  0/101]  eta: 0:02:08  lr: 0.000100  loss: 0.2281 (0.2281)  loss_classifier: 0.0942 (0.0942)  loss_box_reg: 0.0702 (0.0702)  loss_objectness: 0.0597 (0.0597)  loss_rpn_box_reg: 0.0040 (0.0040)  time: 1.2710  data: 0.0820  max mem: 3217
# Epoch: [14]  [ 20/101]  eta: 0:02:06  lr: 0.000100  loss: 0.7811 (0.7219)  loss_classifier: 0.3651 (0.3413)  loss_box_reg: 0.2648 (0.2458)  loss_objectness: 0.0900 (0.0909)  loss_rpn_box_reg: 0.0473 (0.0439)  time: 1.5764  data: 0.2026  max mem: 3217
# Epoch: [14]  [ 40/101]  eta: 0:01:42  lr: 0.000100  loss: 0.8166 (0.7478)  loss_classifier: 0.3829 (0.3517)  loss_box_reg: 0.2730 (0.2590)  loss_objectness: 0.0920 (0.0922)  loss_rpn_box_reg: 0.0498 (0.0449)  time: 1.8212  data: 0.2486  max mem: 3217
# Epoch: [14]  [ 60/101]  eta: 0:01:12  lr: 0.000100  loss: 0.8219 (0.7823)  loss_classifier: 0.3826 (0.3630)  loss_box_reg: 0.2859 (0.2731)  loss_objectness: 0.0967 (0.0969)  loss_rpn_box_reg: 0.0564 (0.0493)  time: 1.9024  data: 0.2685  max mem: 3217
# Epoch: [14]  [ 80/101]  eta: 0:00:37  lr: 0.000100  loss: 0.4561 (0.7522)  loss_classifier: 0.2228 (0.3491)  loss_box_reg: 0.1363 (0.2615)  loss_objectness: 0.0766 (0.0944)  loss_rpn_box_reg: 0.0204 (0.0472)  time: 1.8825  data: 0.2064  max mem: 3217
# Epoch: [14]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.8259 (0.7484)  loss_classifier: 0.3803 (0.3475)  loss_box_reg: 0.2670 (0.2582)  loss_objectness: 0.1089 (0.0948)  loss_rpn_box_reg: 0.0570 (0.0480)  time: 1.7134  data: 0.2186  max mem: 3217
# Epoch: [14] Total time: 0:02:59 (1.7742 s / it)
# Test:  [ 0/58]  eta: 0:00:30  model_time: 0.3256 (0.3256)  evaluator_time: 0.0045 (0.0045)  time: 0.5238  data: 0.1867  max mem: 3217
# Test:  [57/58]  eta: 0:00:00  model_time: 0.1692 (0.1809)  evaluator_time: 0.0015 (0.0030)  time: 0.2816  data: 0.0973  max mem: 3217
# Test: Total time: 0:00:17 (0.3019 s / it)
# Averaged stats: model_time: 0.1692 (0.1809)  evaluator_time: 0.0015 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.095
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.108
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.108
# Epoch: [15]  [  0/101]  eta: 0:03:24  lr: 0.000100  loss: 0.9497 (0.9497)  loss_classifier: 0.4457 (0.4457)  loss_box_reg: 0.3273 (0.3273)  loss_objectness: 0.1080 (0.1080)  loss_rpn_box_reg: 0.0687 (0.0687)  time: 2.0233  data: 0.2582  max mem: 3217
# Epoch: [15]  [ 20/101]  eta: 0:02:15  lr: 0.000100  loss: 0.7782 (0.6428)  loss_classifier: 0.3675 (0.3018)  loss_box_reg: 0.2699 (0.2164)  loss_objectness: 0.0866 (0.0859)  loss_rpn_box_reg: 0.0344 (0.0387)  time: 1.6574  data: 0.1989  max mem: 3217
# Epoch: [15]  [ 40/101]  eta: 0:01:42  lr: 0.000100  loss: 0.8201 (0.7203)  loss_classifier: 0.3672 (0.3365)  loss_box_reg: 0.2614 (0.2404)  loss_objectness: 0.0886 (0.0956)  loss_rpn_box_reg: 0.0539 (0.0478)  time: 1.7000  data: 0.2412  max mem: 3217
# Epoch: [15]  [ 60/101]  eta: 0:01:09  lr: 0.000100  loss: 0.8270 (0.7443)  loss_classifier: 0.3950 (0.3485)  loss_box_reg: 0.2644 (0.2500)  loss_objectness: 0.1136 (0.0970)  loss_rpn_box_reg: 0.0537 (0.0488)  time: 1.7253  data: 0.2193  max mem: 3217
# Epoch: [15]  [ 80/101]  eta: 0:00:35  lr: 0.000100  loss: 0.6626 (0.7230)  loss_classifier: 0.3121 (0.3389)  loss_box_reg: 0.2413 (0.2447)  loss_objectness: 0.0694 (0.0933)  loss_rpn_box_reg: 0.0280 (0.0461)  time: 1.6406  data: 0.1841  max mem: 3217
# Epoch: [15]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.7857 (0.7414)  loss_classifier: 0.3572 (0.3456)  loss_box_reg: 0.2618 (0.2550)  loss_objectness: 0.0923 (0.0935)  loss_rpn_box_reg: 0.0448 (0.0473)  time: 1.7033  data: 0.2147  max mem: 3217
# Epoch: [15] Total time: 0:02:50 (1.6887 s / it)
# Epoch: [16]  [  0/101]  eta: 0:03:13  lr: 0.000100  loss: 0.8697 (0.8697)  loss_classifier: 0.3869 (0.3869)  loss_box_reg: 0.3034 (0.3034)  loss_objectness: 0.1221 (0.1221)  loss_rpn_box_reg: 0.0573 (0.0573)  time: 1.9187  data: 0.2659  max mem: 3217
# Epoch: [16]  [ 20/101]  eta: 0:02:13  lr: 0.000100  loss: 0.7730 (0.8021)  loss_classifier: 0.3648 (0.3676)  loss_box_reg: 0.2601 (0.2803)  loss_objectness: 0.0907 (0.1012)  loss_rpn_box_reg: 0.0411 (0.0531)  time: 1.6291  data: 0.2246  max mem: 3217
# Epoch: [16]  [ 40/101]  eta: 0:01:43  lr: 0.000100  loss: 0.7695 (0.7267)  loss_classifier: 0.3623 (0.3345)  loss_box_reg: 0.2814 (0.2541)  loss_objectness: 0.0832 (0.0916)  loss_rpn_box_reg: 0.0368 (0.0465)  time: 1.7527  data: 0.1823  max mem: 3217
# Epoch: [16]  [ 60/101]  eta: 0:01:12  lr: 0.000100  loss: 0.6987 (0.7186)  loss_classifier: 0.3464 (0.3305)  loss_box_reg: 0.2569 (0.2515)  loss_objectness: 0.0801 (0.0907)  loss_rpn_box_reg: 0.0317 (0.0459)  time: 1.8865  data: 0.1977  max mem: 3217
# Epoch: [16]  [ 80/101]  eta: 0:00:37  lr: 0.000100  loss: 0.7659 (0.7602)  loss_classifier: 0.3588 (0.3513)  loss_box_reg: 0.2689 (0.2639)  loss_objectness: 0.1006 (0.0954)  loss_rpn_box_reg: 0.0500 (0.0496)  time: 1.8610  data: 0.2467  max mem: 3217
# Epoch: [16]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.6186 (0.7386)  loss_classifier: 0.3098 (0.3415)  loss_box_reg: 0.2499 (0.2556)  loss_objectness: 0.0714 (0.0937)  loss_rpn_box_reg: 0.0310 (0.0477)  time: 1.6820  data: 0.1962  max mem: 3217
# Epoch: [16] Total time: 0:02:58 (1.7639 s / it)
# Epoch: [17]  [  0/101]  eta: 0:02:55  lr: 0.000100  loss: 0.1889 (0.1889)  loss_classifier: 0.0674 (0.0674)  loss_box_reg: 0.0579 (0.0579)  loss_objectness: 0.0571 (0.0571)  loss_rpn_box_reg: 0.0065 (0.0065)  time: 1.7332  data: 0.0865  max mem: 3217
# Epoch: [17]  [ 20/101]  eta: 0:02:19  lr: 0.000100  loss: 0.7144 (0.5815)  loss_classifier: 0.3120 (0.2648)  loss_box_reg: 0.2193 (0.1952)  loss_objectness: 0.0761 (0.0830)  loss_rpn_box_reg: 0.0386 (0.0384)  time: 1.7266  data: 0.1855  max mem: 3217
# Epoch: [17]  [ 40/101]  eta: 0:01:42  lr: 0.000100  loss: 0.6073 (0.6287)  loss_classifier: 0.3053 (0.2919)  loss_box_reg: 0.1926 (0.2153)  loss_objectness: 0.0783 (0.0828)  loss_rpn_box_reg: 0.0283 (0.0388)  time: 1.6482  data: 0.1904  max mem: 3217
# Epoch: [17]  [ 60/101]  eta: 0:01:10  lr: 0.000100  loss: 0.7142 (0.6555)  loss_classifier: 0.3339 (0.3011)  loss_box_reg: 0.2576 (0.2276)  loss_objectness: 0.0788 (0.0852)  loss_rpn_box_reg: 0.0367 (0.0415)  time: 1.7680  data: 0.1943  max mem: 3217
# Epoch: [17]  [ 80/101]  eta: 0:00:36  lr: 0.000100  loss: 0.7231 (0.6962)  loss_classifier: 0.3299 (0.3206)  loss_box_reg: 0.2528 (0.2414)  loss_objectness: 0.0988 (0.0896)  loss_rpn_box_reg: 0.0440 (0.0445)  time: 1.7457  data: 0.2337  max mem: 3217
# Epoch: [17]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.8005 (0.7307)  loss_classifier: 0.3715 (0.3368)  loss_box_reg: 0.2526 (0.2515)  loss_objectness: 0.1125 (0.0945)  loss_rpn_box_reg: 0.0570 (0.0479)  time: 1.7479  data: 0.2487  max mem: 3217
# Epoch: [17] Total time: 0:02:54 (1.7274 s / it)
# Epoch: [18]  [  0/101]  eta: 0:03:33  lr: 0.000100  loss: 0.6164 (0.6164)  loss_classifier: 0.3193 (0.3193)  loss_box_reg: 0.1981 (0.1981)  loss_objectness: 0.0704 (0.0704)  loss_rpn_box_reg: 0.0286 (0.0286)  time: 2.1095  data: 0.2623  max mem: 3217
# Epoch: [18]  [ 20/101]  eta: 0:02:20  lr: 0.000100  loss: 0.7673 (0.8574)  loss_classifier: 0.3670 (0.3943)  loss_box_reg: 0.2703 (0.3078)  loss_objectness: 0.0918 (0.1003)  loss_rpn_box_reg: 0.0442 (0.0550)  time: 1.7126  data: 0.2286  max mem: 3217
# Epoch: [18]  [ 40/101]  eta: 0:01:46  lr: 0.000100  loss: 0.7031 (0.7687)  loss_classifier: 0.3398 (0.3544)  loss_box_reg: 0.2535 (0.2715)  loss_objectness: 0.0742 (0.0944)  loss_rpn_box_reg: 0.0385 (0.0484)  time: 1.7760  data: 0.2029  max mem: 3217
# Epoch: [18]  [ 60/101]  eta: 0:01:10  lr: 0.000100  loss: 0.7632 (0.7712)  loss_classifier: 0.3346 (0.3539)  loss_box_reg: 0.2482 (0.2711)  loss_objectness: 0.0912 (0.0964)  loss_rpn_box_reg: 0.0573 (0.0497)  time: 1.6822  data: 0.2153  max mem: 3217
# Epoch: [18]  [ 80/101]  eta: 0:00:36  lr: 0.000100  loss: 0.6931 (0.7413)  loss_classifier: 0.2880 (0.3401)  loss_box_reg: 0.2491 (0.2597)  loss_objectness: 0.0736 (0.0934)  loss_rpn_box_reg: 0.0329 (0.0481)  time: 1.7476  data: 0.1949  max mem: 3217
# Epoch: [18]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.7150 (0.7318)  loss_classifier: 0.3453 (0.3358)  loss_box_reg: 0.2476 (0.2555)  loss_objectness: 0.0806 (0.0931)  loss_rpn_box_reg: 0.0319 (0.0475)  time: 1.7268  data: 0.2002  max mem: 3217
# Epoch: [18] Total time: 0:02:55 (1.7328 s / it)
# Epoch: [19]  [  0/101]  eta: 0:03:06  lr: 0.000100  loss: 0.8047 (0.8047)  loss_classifier: 0.3509 (0.3509)  loss_box_reg: 0.3348 (0.3348)  loss_objectness: 0.0772 (0.0772)  loss_rpn_box_reg: 0.0417 (0.0417)  time: 1.8485  data: 0.2048  max mem: 3217
# Epoch: [19]  [ 20/101]  eta: 0:02:23  lr: 0.000100  loss: 0.7380 (0.6433)  loss_classifier: 0.3496 (0.2975)  loss_box_reg: 0.2462 (0.2206)  loss_objectness: 0.0723 (0.0841)  loss_rpn_box_reg: 0.0454 (0.0411)  time: 1.7632  data: 0.1970  max mem: 3217
# Epoch: [19]  [ 40/101]  eta: 0:01:46  lr: 0.000100  loss: 0.7408 (0.7061)  loss_classifier: 0.3454 (0.3255)  loss_box_reg: 0.2674 (0.2476)  loss_objectness: 0.0802 (0.0876)  loss_rpn_box_reg: 0.0512 (0.0455)  time: 1.7148  data: 0.2145  max mem: 3217
# Epoch: [19]  [ 60/101]  eta: 0:01:11  lr: 0.000100  loss: 0.7030 (0.7243)  loss_classifier: 0.3408 (0.3344)  loss_box_reg: 0.2784 (0.2532)  loss_objectness: 0.0795 (0.0900)  loss_rpn_box_reg: 0.0396 (0.0468)  time: 1.7170  data: 0.2102  max mem: 3217
# Epoch: [19]  [ 80/101]  eta: 0:00:36  lr: 0.000100  loss: 0.7485 (0.7025)  loss_classifier: 0.3459 (0.3235)  loss_box_reg: 0.2591 (0.2452)  loss_objectness: 0.0757 (0.0889)  loss_rpn_box_reg: 0.0376 (0.0449)  time: 1.6677  data: 0.1855  max mem: 3217
# Epoch: [19]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.8288 (0.7250)  loss_classifier: 0.3627 (0.3316)  loss_box_reg: 0.2737 (0.2534)  loss_objectness: 0.1109 (0.0922)  loss_rpn_box_reg: 0.0671 (0.0478)  time: 1.7853  data: 0.2363  max mem: 3217
# Epoch: [19] Total time: 0:02:54 (1.7308 s / it)
# Test:  [ 0/58]  eta: 0:00:37  model_time: 0.4124 (0.4124)  evaluator_time: 0.0050 (0.0050)  time: 0.6387  data: 0.2143  max mem: 3217
# Test:  [57/58]  eta: 0:00:00  model_time: 0.1883 (0.2020)  evaluator_time: 0.0020 (0.0027)  time: 0.3051  data: 0.1010  max mem: 3217
# Test: Total time: 0:00:18 (0.3270 s / it)
# Averaged stats: model_time: 0.1883 (0.2020)  evaluator_time: 0.0020 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.028
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.076
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.080
# Epoch: [20]  [  0/101]  eta: 0:02:50  lr: 0.000100  loss: 0.5977 (0.5977)  loss_classifier: 0.2418 (0.2418)  loss_box_reg: 0.2470 (0.2470)  loss_objectness: 0.0781 (0.0781)  loss_rpn_box_reg: 0.0308 (0.0308)  time: 1.6930  data: 0.1227  max mem: 3217
# Epoch: [20]  [ 20/101]  eta: 0:02:18  lr: 0.000100  loss: 0.7669 (0.7848)  loss_classifier: 0.3441 (0.3600)  loss_box_reg: 0.2602 (0.2691)  loss_objectness: 0.0994 (0.1015)  loss_rpn_box_reg: 0.0570 (0.0542)  time: 1.7131  data: 0.2306  max mem: 3217
# Epoch: [20]  [ 40/101]  eta: 0:01:43  lr: 0.000100  loss: 0.8552 (0.8197)  loss_classifier: 0.3943 (0.3741)  loss_box_reg: 0.3113 (0.2810)  loss_objectness: 0.1292 (0.1072)  loss_rpn_box_reg: 0.0714 (0.0574)  time: 1.6773  data: 0.2507  max mem: 3217
# Epoch: [20]  [ 60/101]  eta: 0:01:09  lr: 0.000100  loss: 0.7146 (0.7727)  loss_classifier: 0.3327 (0.3534)  loss_box_reg: 0.2451 (0.2663)  loss_objectness: 0.0786 (0.1006)  loss_rpn_box_reg: 0.0399 (0.0525)  time: 1.6938  data: 0.1993  max mem: 3217
# Epoch: [20]  [ 80/101]  eta: 0:00:35  lr: 0.000100  loss: 0.7086 (0.7466)  loss_classifier: 0.3028 (0.3397)  loss_box_reg: 0.2745 (0.2603)  loss_objectness: 0.0696 (0.0969)  loss_rpn_box_reg: 0.0297 (0.0498)  time: 1.6187  data: 0.1831  max mem: 3217
# Epoch: [20]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.7020 (0.7262)  loss_classifier: 0.3395 (0.3316)  loss_box_reg: 0.2446 (0.2533)  loss_objectness: 0.0700 (0.0936)  loss_rpn_box_reg: 0.0306 (0.0477)  time: 1.6265  data: 0.1851  max mem: 3217
# Epoch: [20] Total time: 0:02:48 (1.6662 s / it)
# Epoch: [21]  [  0/101]  eta: 0:02:38  lr: 0.000100  loss: 0.3688 (0.3688)  loss_classifier: 0.1733 (0.1733)  loss_box_reg: 0.1278 (0.1278)  loss_objectness: 0.0543 (0.0543)  loss_rpn_box_reg: 0.0133 (0.0133)  time: 1.5661  data: 0.1214  max mem: 3217
# Epoch: [21]  [ 20/101]  eta: 0:02:21  lr: 0.000100  loss: 0.7329 (0.6289)  loss_classifier: 0.3308 (0.2850)  loss_box_reg: 0.2658 (0.2249)  loss_objectness: 0.0836 (0.0810)  loss_rpn_box_reg: 0.0399 (0.0381)  time: 1.7531  data: 0.1895  max mem: 3217
# Epoch: [21]  [ 40/101]  eta: 0:01:47  lr: 0.000100  loss: 0.8016 (0.7005)  loss_classifier: 0.3463 (0.3202)  loss_box_reg: 0.2631 (0.2468)  loss_objectness: 0.0993 (0.0902)  loss_rpn_box_reg: 0.0419 (0.0434)  time: 1.7649  data: 0.2205  max mem: 3217
# Epoch: [21]  [ 60/101]  eta: 0:01:12  lr: 0.000100  loss: 0.7164 (0.7084)  loss_classifier: 0.3422 (0.3224)  loss_box_reg: 0.2700 (0.2495)  loss_objectness: 0.0880 (0.0913)  loss_rpn_box_reg: 0.0371 (0.0452)  time: 1.7707  data: 0.2011  max mem: 3217
# Epoch: [21]  [ 80/101]  eta: 0:00:36  lr: 0.000100  loss: 0.7801 (0.7266)  loss_classifier: 0.3570 (0.3326)  loss_box_reg: 0.2708 (0.2539)  loss_objectness: 0.0934 (0.0924)  loss_rpn_box_reg: 0.0598 (0.0477)  time: 1.6890  data: 0.2219  max mem: 3217
# Epoch: [21]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.7456 (0.7245)  loss_classifier: 0.3482 (0.3316)  loss_box_reg: 0.2466 (0.2527)  loss_objectness: 0.0834 (0.0927)  loss_rpn_box_reg: 0.0408 (0.0475)  time: 1.6079  data: 0.2105  max mem: 3217
# Epoch: [21] Total time: 0:02:53 (1.7157 s / it)
# Epoch: [22]  [  0/101]  eta: 0:03:40  lr: 0.000100  loss: 0.8256 (0.8256)  loss_classifier: 0.3666 (0.3666)  loss_box_reg: 0.2617 (0.2617)  loss_objectness: 0.1298 (0.1298)  loss_rpn_box_reg: 0.0675 (0.0675)  time: 2.1881  data: 0.2897  max mem: 3217
# Epoch: [22]  [ 20/101]  eta: 0:02:15  lr: 0.000100  loss: 0.6834 (0.6517)  loss_classifier: 0.3252 (0.2978)  loss_box_reg: 0.2357 (0.2174)  loss_objectness: 0.0599 (0.0907)  loss_rpn_box_reg: 0.0259 (0.0458)  time: 1.6414  data: 0.2001  max mem: 3217
# Epoch: [22]  [ 40/101]  eta: 0:01:42  lr: 0.000100  loss: 0.7372 (0.6997)  loss_classifier: 0.3427 (0.3204)  loss_box_reg: 0.2518 (0.2390)  loss_objectness: 0.0868 (0.0926)  loss_rpn_box_reg: 0.0413 (0.0477)  time: 1.6853  data: 0.2108  max mem: 3217
# Epoch: [22]  [ 60/101]  eta: 0:01:08  lr: 0.000100  loss: 0.7083 (0.7175)  loss_classifier: 0.3271 (0.3273)  loss_box_reg: 0.2579 (0.2500)  loss_objectness: 0.0789 (0.0920)  loss_rpn_box_reg: 0.0376 (0.0482)  time: 1.6914  data: 0.2038  max mem: 3217
# Epoch: [22]  [ 80/101]  eta: 0:00:35  lr: 0.000100  loss: 0.7283 (0.7268)  loss_classifier: 0.3360 (0.3309)  loss_box_reg: 0.2500 (0.2532)  loss_objectness: 0.0844 (0.0941)  loss_rpn_box_reg: 0.0420 (0.0485)  time: 1.6379  data: 0.2154  max mem: 3217
# Epoch: [22]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.7361 (0.7228)  loss_classifier: 0.3469 (0.3292)  loss_box_reg: 0.2536 (0.2527)  loss_objectness: 0.0870 (0.0936)  loss_rpn_box_reg: 0.0422 (0.0474)  time: 1.7404  data: 0.2032  max mem: 3217
# Epoch: [22] Total time: 0:02:50 (1.6844 s / it)
# Epoch: [23]  [  0/101]  eta: 0:02:54  lr: 0.000100  loss: 0.8710 (0.8710)  loss_classifier: 0.3967 (0.3967)  loss_box_reg: 0.2767 (0.2767)  loss_objectness: 0.1183 (0.1183)  loss_rpn_box_reg: 0.0793 (0.0793)  time: 1.7247  data: 0.2395  max mem: 3217
# Epoch: [23]  [ 20/101]  eta: 0:02:11  lr: 0.000100  loss: 0.7064 (0.6979)  loss_classifier: 0.3289 (0.3135)  loss_box_reg: 0.2451 (0.2378)  loss_objectness: 0.0872 (0.0955)  loss_rpn_box_reg: 0.0409 (0.0510)  time: 1.6217  data: 0.2080  max mem: 3217
# Epoch: [23]  [ 40/101]  eta: 0:01:43  lr: 0.000100  loss: 0.7908 (0.7259)  loss_classifier: 0.3477 (0.3259)  loss_box_reg: 0.2609 (0.2487)  loss_objectness: 0.1123 (0.0995)  loss_rpn_box_reg: 0.0570 (0.0519)  time: 1.7816  data: 0.2237  max mem: 3217
# Epoch: [23]  [ 60/101]  eta: 0:01:10  lr: 0.000100  loss: 0.7099 (0.7199)  loss_classifier: 0.3320 (0.3275)  loss_box_reg: 0.2387 (0.2486)  loss_objectness: 0.0861 (0.0955)  loss_rpn_box_reg: 0.0381 (0.0482)  time: 1.7371  data: 0.1921  max mem: 3217
# Epoch: [23]  [ 80/101]  eta: 0:00:36  lr: 0.000100  loss: 0.7596 (0.7144)  loss_classifier: 0.3556 (0.3252)  loss_box_reg: 0.2666 (0.2472)  loss_objectness: 0.0715 (0.0939)  loss_rpn_box_reg: 0.0483 (0.0481)  time: 1.7647  data: 0.2086  max mem: 3217
# Epoch: [23]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.7068 (0.7105)  loss_classifier: 0.3209 (0.3231)  loss_box_reg: 0.2375 (0.2472)  loss_objectness: 0.0831 (0.0929)  loss_rpn_box_reg: 0.0494 (0.0474)  time: 1.7694  data: 0.1995  max mem: 3217
# Epoch: [23] Total time: 0:02:55 (1.7349 s / it)
# Epoch: [24]  [  0/101]  eta: 0:03:04  lr: 0.000100  loss: 1.3353 (1.3353)  loss_classifier: 0.6134 (0.6134)  loss_box_reg: 0.5017 (0.5017)  loss_objectness: 0.1382 (0.1382)  loss_rpn_box_reg: 0.0820 (0.0820)  time: 1.8252  data: 0.3541  max mem: 3217
# Epoch: [24]  [ 20/101]  eta: 0:02:19  lr: 0.000100  loss: 0.7135 (0.7076)  loss_classifier: 0.3242 (0.3209)  loss_box_reg: 0.2446 (0.2496)  loss_objectness: 0.0870 (0.0894)  loss_rpn_box_reg: 0.0463 (0.0477)  time: 1.7170  data: 0.2051  max mem: 3217
# Epoch: [24]  [ 40/101]  eta: 0:01:44  lr: 0.000100  loss: 0.6243 (0.6728)  loss_classifier: 0.2911 (0.3030)  loss_box_reg: 0.2248 (0.2356)  loss_objectness: 0.0658 (0.0878)  loss_rpn_box_reg: 0.0368 (0.0464)  time: 1.7070  data: 0.2012  max mem: 3217
# Epoch: [24]  [ 60/101]  eta: 0:01:11  lr: 0.000100  loss: 0.7251 (0.6792)  loss_classifier: 0.3404 (0.3076)  loss_box_reg: 0.2448 (0.2383)  loss_objectness: 0.0795 (0.0868)  loss_rpn_box_reg: 0.0459 (0.0464)  time: 1.7729  data: 0.2003  max mem: 3217
# Epoch: [24]  [ 80/101]  eta: 0:00:36  lr: 0.000100  loss: 0.7452 (0.6841)  loss_classifier: 0.3284 (0.3083)  loss_box_reg: 0.2531 (0.2400)  loss_objectness: 0.0970 (0.0888)  loss_rpn_box_reg: 0.0533 (0.0471)  time: 1.7733  data: 0.2203  max mem: 3217
# Epoch: [24]  [100/101]  eta: 0:00:01  lr: 0.000100  loss: 0.6632 (0.6820)  loss_classifier: 0.2989 (0.3058)  loss_box_reg: 0.2363 (0.2387)  loss_objectness: 0.0845 (0.0899)  loss_rpn_box_reg: 0.0380 (0.0476)  time: 1.7447  data: 0.2173  max mem: 3217
# Epoch: [24] Total time: 0:02:56 (1.7439 s / it)
# Test:  [ 0/58]  eta: 0:00:26  model_time: 0.2769 (0.2769)  evaluator_time: 0.0040 (0.0040)  time: 0.4630  data: 0.1738  max mem: 3217
# Test:  [57/58]  eta: 0:00:00  model_time: 0.2703 (0.2734)  evaluator_time: 0.0020 (0.0028)  time: 0.4038  data: 0.1089  max mem: 3217
# Test: Total time: 0:00:23 (0.4006 s / it)
# Averaged stats: model_time: 0.2703 (0.2734)  evaluator_time: 0.0020 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.040
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.054
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.162
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.162
# Training time 1:21:48

# %%
import pickle
with open('./model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
# Inferencja na zadanym obrazie
preprocess = M.FasterRCNN_ResNet50_FPN_Weights.COCO_V1.transforms() # to wystarczy pobrać raz
img = read_image(os.path.join(DATASET_ROOT, 'test/IMG_0159_JPG.rf.1cf4f243b5072d63e492711720df35f7.jpg'))
batch = [preprocess(img).to(DEVICE)]
prediction = model(batch)[0]
# Rysowanie predykcji - wygodny gotowiec
box = draw_bounding_boxes(
  img,
  boxes=prediction['boxes'],
  labels=[chess_train.coco.cats[i.item()]['name'] for i in prediction['labels']],
  colors='red',
  width=4,
)
to_pil_image(box.detach()).show()

# %% [markdown]
# ---
# ### Zadanie 1
#
# Zbadaj wpływ parametrów inferencji **głowic `RoIHeads`**, progu prawdopodobieństwa (`score_thresh`) i progu NMS (`nms_thresh`), na działanie modelu. Wykorzystaj funkcję `evaluate` aby zmierzyć zmianę jakości predykcji, ale przebadaj też efekty wizualnie, wyświetlając predykcje dla kilku obrazów ze zbioru walidacyjnego i kilku spoza zbioru (folder `wild`). _W finalnej wersji pozostaw tylko wybrane interesujące przykłady._

# %% [markdown]
# ### Zadanie 2a
#
# Zwizualizuj propozycje rejonów wygenerowane przez RPN i porównaj z ostateczną predykcją.
#
# W tym celu konieczne będzie manualne wykonanie fragmentu metody `GeneralizedRCNN::forward` (patrz: [kod](https://github.com/pytorch/vision/blob/c35d3855ccbfa6a36e6ae6337a1f2c721c1f1e78/torchvision/models/detection/generalized_rcnn.py#L46), link do wersji najnowszej na listopad 2023).
# Wszystkie fragmenty związane z uczeniem możesz rzecz jasna pominąć; chodzi o wyciągnięcie obiektu `proposals`.
# Nie zapomnij o wykonaniu powrotnej transformacji! (Po co?)

# %% [markdown]
# ### Zadanie 2b
#
# Zbadaj wpływ progu NMS _na etapie propozycji_ na jakość predykcji oraz czas ich uzyskania.
# Jak w poprzednich zadaniach, postaraj się nie ograniczyć tylko do pokazania metryk, ale pokaż wizualizacje (propozycji i predykcji) dla **wybranych** przykładów.
